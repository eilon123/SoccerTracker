# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

import sys
sys.path.append(r'C:\Users\Admin\sem 9\project\Soccer-Tracker')

# %%
import matplotlib.pyplot as plt
from IPython.display import display
from soccer_tracker.dataset_handler import SoccerHandler
from soccer_tracker.track_models.simple_model import SimpleTracker
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\Admin\sem 9\project\Soccer-Tracker\soccer_tracker\detection_models\retinanet\retinanet.py:20: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\Admin\sem 9\project\Soccer-Tracker\soccer_tracker\detection_models\retinanet\retinanet.py:22: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# c:\python\python37\lib\site-packages\sklearn\utils\linear_assignment_.py:21: DeprecationWarning: The linear_assignment_ module is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   DeprecationWarning)

# %%
data_handler = SoccerHandler()

# %%
tracker = SimpleTracker(data_handler)

# %%
import numpy as np
import cv2
def add_rects(image, boxes, scores, labels):
    new_image = np.array(image)
    
    track_bbs_ids = tracker.mot_tracker.update(boxes[0])
    track_bbs_ids = track_bbs_ids.astype(np.int)

    # draw a bounding box rectangle and label on the image
    for tr in track_bbs_ids:
        color = [int(c) for c in tracker.COLORS[tr[-1]]]
        x1 = tr[0]
        y1 = tr[1]
        x2 = tr[2]
        y2 = tr[3]
        cv2.rectangle(new_image, (x1, y1), (x2, y2), color, 2)
        cv2.putText(new_image, str(tr[-1]), (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
    
    return new_image

# %%
results_generator = tracker.data_handler.detections_generator()
image, (boxes, scores, labels) = next(results_generator)
print(len(boxes[0]))
before_image = add_rects(image, boxes, scores, labels)
cv2.imwrite('before.png', before_image)

# boxes, scores, labels = SimpleTracker.postprocess(boxes, scores, labels)
print(len(boxes[0]))
after_image = add_rects(image, boxes, scores, labels)
cv2.imwrite('after.png', after_image)
# Out:
# ...
# 300
# c:\python\python37\lib\site-packages\sklearn\utils\linear_assignment_.py:127: DeprecationWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   DeprecationWarning)
# 22
# c:\python\python37\lib\site-packages\sklearn\utils\linear_assignment_.py:127: DeprecationWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   DeprecationWarning)
# True

# %%
# Out:
# True

# %%
for image_tracked in tracker.track():
    pass
# Out:
# ...
# c:\python\python37\lib\site-packages\sklearn\utils\linear_assignment_.py:127: DeprecationWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   DeprecationWarning)
# c:\python\python37\lib\site-packages\sklearn\utils\linear_assignment_.py:127: DeprecationWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   DeprecationWarning)
# c:\python\python37\lib\site-packages\sklearn\utils\linear_assignment_.py:127: DeprecationWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   DeprecationWarning)
# ...
